# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 1 Data Reading : ( excel / csv / json )
def read_data():
    file_path = input("Please enter File Path :")
    file_format = input("Please enter File Format (csv / excel / json) :").lower()
    if file_format == 'csv':
        return pd.read_csv(file_path)
    elif file_format == 'excel':
        return pd.read_excel(file_path)
    elif file_format == 'json':
        return pd.read_json(file_path)
    else:
        raise ValueError("File not available, please choose from 'csv', 'excel', or 'json'.")

# %%
data = read_data()
# Out:
# Please enter File Path : movies.csv
# Please enter File Format (csv / excel / json) : csv

# %%
data
# Out:
#                           Series_Title Certificate  Runtime  \
# 0                                  Her           A  126 min
# 1                                  300           A  117 min
# 2                             21 Grams          UA  124 min
# 3                            25Th Hour           R  135 min
# 4                                50/50           R  100 min
# 5                   A Hard Day'S Night           U   87 min
# 6                       A Star Is Born          UA  136 min
# 7                      American Psycho           A  101 min
# 8                            Apollo 13           U  140 min
# 9                          Baby Driver          UA  113 min
# 10                        Blood Simple           A   99 min
# 11                                Blow           R  124 min
# 12              Breakfast At Tiffany'S           A  115 min
# 13                     Bridge Of Spies          UA  142 min
# 14  Close Encounters Of The Third Kind           U  138 min
# 15                               Creed           A  133 min
# 16                           Dark City           A  100 min
# 17                         Dark Waters       PG-13  126 min
# 18      Dawn Of The Planet Of The Apes          UA  130 min
# 19                  Dazed And Confused           U  102 min
# 20                        Delicatessen           R   99 min
# 21                       Despicable Me           U   95 min
# 22          Die Hard: With A Vengeance           A  128 min
#
#                           Genre  IMDB_Rating  Meta_score  \
# 0        Drama, Romance, Sci-Fi          6.0          90
# 1                 Action, Drama          7.6          52
# 2        Crime, Drama, Thriller          7.6          70
# 3                         Drama          7.6          68
# 4        Comedy, Drama, Romance          7.6          72
# 5        Comedy, Music, Musical          7.6          96
# 6         Drama, Music, Romance          7.6          88
# 7          Comedy, Crime, Drama          7.6          64
# 8     Adventure, Drama, History          7.6          77
# 9          Action, Crime, Drama          7.6          86
# 10       Crime, Drama, Thriller          7.6          82
# 11      Biography, Crime, Drama          7.6          52
# 12       Comedy, Drama, Romance          7.6          76
# 13     Drama, History, Thriller          7.6          81
# 14                Drama, Sci-Fi          7.6          90
# 15                 Drama, Sport          7.6          82
# 16    Mystery, Sci-Fi, Thriller          7.6          66
# 17    Biography, Drama, History          7.6          73
# 18     Action, Adventure, Drama          7.6          79
# 19                       Comedy          7.6          78
# 20                Comedy, Crime          7.6          66
# 21     Animation, Comedy, Crime          7.6          72
# 22  Action, Adventure, Thriller          7.6          58
#
#                  Director  No_of_Votes          Gross Released_date Langunges  \
# 0             Spike Jonze       540772   $25,568,251      1/16/2014   English
# 1             Zack Snyder       732876  $210,614,939       4/5/2007   English
# 2   Alejandro G. Iñárritu       224545   $16,290,476      1/22/2004   English
# 3               Spike Lee       169708   $13,060,843       6/5/2003   English
# 4         Jonathan Levine       315426   $35,014,192       3/8/2012   English
# 5          Richard Lester        40351   $13,780,024       7/7/1964   English
# 6          Bradley Cooper       334312  $215,288,866     10/18/2018   English
# 7             Mary Harron       490062   $15,070,285      4/13/2000   English
# 8              Ron Howard       269197  $173,837,933      8/31/1995   English
# 9            Edgar Wright       439406  $107,825,862      8/10/2017   English
# 10              Joel Coen        87745    $2,150,000      6/27/1985   English
# 11              Ted Demme       240714   $52,990,775       4/4/2001   English
# 12          Blake Edwards       166544   $90,485,605       2/8/1962   English
# 13       Steven Spielberg       287659   $72,313,754     10/22/2015   English
# 14       Steven Spielberg       184966  $132,088,635      1/27/1978   English
# 15           Ryan Coogler       247666  $109,767,581     11/26/2015   English
# 16            Alex Proyas       187927   $14,378,331      5/29/1998   English
# 17            Todd Haynes        60408   $90,485,605       3/5/2020   English
# 18            Matt Reeves       411599  $208,545,589       7/9/2014   English
# 19      Richard Linklater       165465    $7,993,039      5/27/1994   English
# 20              Marc Caro        80487    $1,794,187      4/17/1991    French
# 21          Pierre Coffin       500851  $251,513,985       9/9/2010   English
# 22         John McTiernan       364420  $100,012,499      5/25/1995   English
#
#              budget          revenue country
# 0   $23,000,000.00          48043998      AU
# 1          60000000        454161935      AU
# 2          20000000         59667625      AU
# 3           4500000  $25,344,490.00       AU
# 4           8000000         41334735      AU
# 5            560000          1626784      GB
# 6          36000000        433888866      AU
# 7           8000000         34270285      AU
# 8          65000000        335802271      AU
# 9          34000000        226977991      AU
# 10          1500000          2730877      AU
# 11         30000000         83282296      AU
# 12          2500000          9500000      AU
# 13         40000000        162498338      AU
# 14  $20,000,000.00         340800479      AU
# 15         37000000        173567581      AU
# 16         27000000         27257061      AU
# 17         835001.4         13601384      AU
# 18        170000000        710644566      AU
# 19          6900000          7961889      AU
# 20          4000000          1794187      FR
# 21         69000000        543464573      AU
# 22         90000000        366101666      AU

# %%
# 2 Data Summary
def data_summary(data, target_column):
    #print information
    print("Information about all the columns and their situations and how many rows:\n")
    print(data.info())
    print("______________________________________________\n")
    #value & frequencies
    print("Values and their frequencies in the target column:\n")
    print(data[target_column].value_counts())
    print("______________________________________________\n")
    #Summary coloumn
    print("Summary statistics for the target column:\n")
    print(data[target_column].describe())
    print("______________________________________________\n")
    #repeated value
    print("The most repeated value in the target column:")
    mode_value = data[target_column].mode()
    if not mode_value.empty:
        print(mode_value.values[0])
    else:
        print("No mode exists.")
    print("______________________________________________\n")
    #Mean
    print("The mean of the target column:\n")
    print("Using Pandas:")
    print(data[target_column].mean())
    print("Using NumPy:")
    print(np.mean(data[target_column]))
    print("______________________________________________\n")
    #Max
    print("The highest value of the target column:")
    print(np.max(data[target_column]))
    print("______________________________________________\n")
    #Min
    print("The smallest value of the target column:")
    print(np.min(data[target_column]))
    print("______________________________________________\n")

# %%
data_summary(data, "Series_Title")
# Out:
# Information about all the columns and their situations and how many rows:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   23 non-null     object
#  1   Certificate    23 non-null     object
#  2   Runtime        23 non-null     object
#  3   Genre          23 non-null     object
#  4   IMDB_Rating    23 non-null     float64
#  5   Meta_score     23 non-null     int64
#  6   Director       23 non-null     object
#  7   No_of_Votes    23 non-null     int64
#  8   Gross          23 non-null     object
#  9   Released_date  23 non-null     object
#  10  Langunges      23 non-null     object
#  11  budget         23 non-null     object
#  12  revenue        23 non-null     object
#  13  country        23 non-null     object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 2.6+ KB
# None
# ______________________________________________
#
# Values and their frequencies in the target column:
#
# Series_Title
# Her                                   1
# Breakfast At Tiffany'S                1
# Despicable Me                         1
# Delicatessen                          1
# Dazed And Confused                    1
# Dawn Of The Planet Of The Apes        1
# Dark Waters                           1
# Dark City                             1
# Creed                                 1
# Close Encounters Of The Third Kind    1
# Bridge Of Spies                       1
# Blow                                  1
# 300                                   1
# Blood Simple                          1
# Baby Driver                           1
# Apollo 13                             1
# American Psycho                       1
# A Star Is Born                        1
# A Hard Day'S Night                    1
# 50/50                                 1
# 25Th Hour                             1
# 21 Grams                              1
# Die Hard: With A Vengeance            1
# Name: count, dtype: int64
# ______________________________________________
#
# Summary statistics for the target column:
#
# count      23
# unique     23
# top       Her
# freq        1
# Name: Series_Title, dtype: object
# ______________________________________________
#
# The most repeated value in the target column:
# 21 Grams
# ______________________________________________
#
# The mean of the target column:
#
# Using Pandas:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data_summary(data, "Series_Title")
#
# Cell In[9], line 26, in data_summary(data, target_column)
#      24 print("The mean of the target column:\n")
#      25 print("Using Pandas:")
# ---> 26 print(data[target_column].mean())
#      27 print("Using NumPy:")
#      28 print(np.mean(data[target_column]))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6225, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6217 @doc(make_doc("mean", ndim=1))
#    6218 def mean(
#    6219     self,
#    (...)
#    6223     **kwargs,
#    6224 ):
# -> 6225     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
#   11993         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11949, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11945 nv.validate_func(name, (), kwargs)
#   11947 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11949 return self._reduce(
#   11950     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11951 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6133, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6128     # GH#47500 - change to TypeError to match other methods
#    6129     raise TypeError(
#    6130         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6131         "with non-numeric dtypes."
#    6132     )
# -> 6133 return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\nanops.py:1693, in _ensure_numeric(x)
#    1690 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1691     if isinstance(x, str):
#    1692         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694     try:
#    1695         x = float(x)
#
# TypeError: Could not convert string 'Her30021 Grams25Th Hour50/50A Hard Day'S NightA Star Is BornAmerican PsychoApollo 13Baby DriverBlood SimpleBlowBreakfast At Tiffany'SBridge Of SpiesClose Encounters Of The Third KindCreedDark CityDark WatersDawn Of The Planet Of The ApesDazed And ConfusedDelicatessenDespicable MeDie Hard: With A Vengeance' to numeric

# %%
# 3 Data handling missing value
def clear_missing(data):
    print("First, the rows with missing values:\n")
    empty_rows = data[data.isnull().any(axis=1)]
    print(empty_rows)
    x = input("Do you want to delete or fill the empty cells? (D/F): ").upper()

    if x == "D":
        data = data.dropna()
        return data
    elif x == "F":
        fill_value = input("Enter the value to fill the empty cells: ")
        data = data.fillna(fill_value)
        return data
    else:
        print("Invalid input. Please enter ('D' - delete) or ('F' - fill) missing values.")
        return None

# %%
#creating random "empty" values in the table
data["Empty"] = np.random.randint(0,2,len(data))
data["Empty"] = np.where(data["Empty"] == 0,None,1)

# %%
data["Empty"].value_counts()
# Out:
# Empty
# 1    11
# Name: count, dtype: int64

# %%
#succedded to fill the place with number 1
clear_missing(data)
# Out:
# First, the rows with missing values:
#
#           Series_Title Certificate  Runtime                      Genre  \
# 1                  300           A  117 min              Action, Drama
# 3            25Th Hour           R  135 min                      Drama
# 5   A Hard Day'S Night           U   87 min     Comedy, Music, Musical
# 6       A Star Is Born          UA  136 min      Drama, Music, Romance
# 7      American Psycho           A  101 min       Comedy, Crime, Drama
# 9          Baby Driver          UA  113 min       Action, Crime, Drama
# 11                Blow           R  124 min    Biography, Crime, Drama
# 15               Creed           A  133 min               Drama, Sport
# 16           Dark City           A  100 min  Mystery, Sci-Fi, Thriller
# 19  Dazed And Confused           U  102 min                     Comedy
# 20        Delicatessen           R   99 min              Comedy, Crime
# 21       Despicable Me           U   95 min   Animation, Comedy, Crime
#
#     IMDB_Rating  Meta_score           Director  No_of_Votes          Gross  \
# 1           7.6          52        Zack Snyder       732876  $210,614,939
# 3           7.6          68          Spike Lee       169708   $13,060,843
# 5           7.6          96     Richard Lester        40351   $13,780,024
# 6           7.6          88     Bradley Cooper       334312  $215,288,866
# 7           7.6          64        Mary Harron       490062   $15,070,285
# 9           7.6          86       Edgar Wright       439406  $107,825,862
# 11          7.6          52          Ted Demme       240714   $52,990,775
# 15          7.6          82       Ryan Coogler       247666  $109,767,581
# 16          7.6          66        Alex Proyas       187927   $14,378,331
# 19          7.6          78  Richard Linklater       165465    $7,993,039
# 20          7.6          66          Marc Caro        80487    $1,794,187
# 21          7.6          72      Pierre Coffin       500851  $251,513,985
#
#    Released_date Langunges    budget          revenue country Empty
# 1       4/5/2007   English  60000000        454161935      AU  None
# 3       6/5/2003   English   4500000  $25,344,490.00       AU  None
# 5       7/7/1964   English    560000          1626784      GB  None
# 6     10/18/2018   English  36000000        433888866      AU  None
# 7      4/13/2000   English   8000000         34270285      AU  None
# 9      8/10/2017   English  34000000        226977991      AU  None
# 11      4/4/2001   English  30000000         83282296      AU  None
# 15    11/26/2015   English  37000000        173567581      AU  None
# 16     5/29/1998   English  27000000         27257061      AU  None
# 19     5/27/1994   English   6900000          7961889      AU  None
# 20     4/17/1991    French   4000000          1794187      FR  None
# 21      9/9/2010   English  69000000        543464573      AU  None
# Do you want to delete or fill the empty cells? (D/F):  F
# Enter the value to fill the empty cells:  1
#                           Series_Title Certificate  Runtime  \
# 0                                  Her           A  126 min
# 1                                  300           A  117 min
# 2                             21 Grams          UA  124 min
# 3                            25Th Hour           R  135 min
#                           Series_Title Certificate  Runtime  \
# 0                                  Her           A  126 min
# 2                             21 Grams          UA  124 min
# 4                                50/50           R  100 min
# 8                            Apollo 13           U  140 min
# 10                        Blood Simple           A   99 min
# 12              Breakfast At Tiffany'S           A  115 min
# 13                     Bridge Of Spies          UA  142 min
# 14  Close Encounters Of The Third Kind           U  138 min
# 17                         Dark Waters       PG-13  126 min
# 18      Dawn Of The Planet Of The Apes          UA  130 min
# 22          Die Hard: With A Vengeance           A  128 min
#
#                           Genre  IMDB_Rating  Meta_score  \
# 0        Drama, Romance, Sci-Fi          6.0          90
# 2        Crime, Drama, Thriller          7.6          70
# 4        Comedy, Drama, Romance          7.6          72
# 8     Adventure, Drama, History          7.6          77
# 10       Crime, Drama, Thriller          7.6          82
# 12       Comedy, Drama, Romance          7.6          76
# 13     Drama, History, Thriller          7.6          81
# 14                Drama, Sci-Fi          7.6          90
# 17    Biography, Drama, History          7.6          73
# 18     Action, Adventure, Drama          7.6          79
# 22  Action, Adventure, Thriller          7.6          58
#
#                  Director  No_of_Votes          Gross Released_date Langunges  \
# 0             Spike Jonze       540772   $25,568,251      1/16/2014   English
# 2   Alejandro G. Iñárritu       224545   $16,290,476      1/22/2004   English
# 4         Jonathan Levine       315426   $35,014,192       3/8/2012   English
# 8              Ron Howard       269197  $173,837,933      8/31/1995   English
# 10              Joel Coen        87745    $2,150,000      6/27/1985   English
# 12          Blake Edwards       166544   $90,485,605       2/8/1962   English
# 13       Steven Spielberg       287659   $72,313,754     10/22/2015   English
# 14       Steven Spielberg       184966  $132,088,635      1/27/1978   English
# 17            Todd Haynes        60408   $90,485,605       3/5/2020   English
# 18            Matt Reeves       411599  $208,545,589       7/9/2014   English
# 22         John McTiernan       364420  $100,012,499      5/25/1995   English
#
#              budget    revenue country Empty
# 0   $23,000,000.00    48043998      AU     1
# 2          20000000   59667625      AU     1
# 4           8000000   41334735      AU     1
# 8          65000000  335802271      AU     1
# 10          1500000    2730877      AU     1
# 12          2500000    9500000      AU     1
# 13         40000000  162498338      AU     1
# 14  $20,000,000.00   340800479      AU     1
# 17         835001.4   13601384      AU     1
# 18        170000000  710644566      AU     1
# 22         90000000  366101666      AU     1

# %%
# 4 Categorical Data Encoding
def describe_categorical_data(data, category_column):
    return data.groupby(category_column).describe()

def encode_categorical_data(data):
    return pd.get_dummies(data)

# %%
#last step ( encoding )
encode_categorical_data(data)
# Out:
#     IMDB_Rating  Meta_score  No_of_Votes  Series_Title_21 Grams  \
# 0           6.0          90       540772                  False
# 1           7.6          52       732876                  False
# 2           7.6          70       224545                   True
# 3           7.6          68       169708                  False
# 4           7.6          72       315426                  False
# 5           7.6          96        40351                  False
# 6           7.6          88       334312                  False
# 7           7.6          64       490062                  False
# 8           7.6          77       269197                  False
# 9           7.6          86       439406                  False
# 10          7.6          82        87745                  False
# 11          7.6          52       240714                  False
# 12          7.6          76       166544                  False
# 13          7.6          81       287659                  False
# 14          7.6          90       184966                  False
# 15          7.6          82       247666                  False
# 16          7.6          66       187927                  False
# 17          7.6          73        60408                  False
# 18          7.6          79       411599                  False
# 19          7.6          78       165465                  False
# 20          7.6          66        80487                  False
# 21          7.6          72       500851                  False
# 22          7.6          58       364420                  False
#
#     Series_Title_25Th Hour  Series_Title_300  Series_Title_50/50  \
# 0                    False             False               False
# 1                    False              True               False
# 2                    False             False               False
# 3                     True             False               False
# 4                    False             False                True
# 5                    False             False               False
# 6                    False             False               False
# 7                    False             False               False
# 8                    False             False               False
# 9                    False             False               False
# 10                   False             False               False
# 11                   False             False               False
# 12                   False             False               False
# 13                   False             False               False
# 14                   False             False               False
# 15                   False             False               False
# 16                   False             False               False
# 17                   False             False               False
# 18                   False             False               False
# 19                   False             False               False
# 20                   False             False               False
# 21                   False             False               False
# 22                   False             False               False
#
#     Series_Title_A Hard Day'S Night  Series_Title_A Star Is Born  \
# 0                             False                        False
# 1                             False                        False
# 2                             False                        False
# 3                             False                        False
# 4                             False                        False
# 5                              True                        False
# 6                             False                         True
# 7                             False                        False
# 8                             False                        False
# 9                             False                        False
# 10                            False                        False
# 11                            False                        False
# 12                            False                        False
# 13                            False                        False
# 14                            False                        False
# 15                            False                        False
# 16                            False                        False
# 17                            False                        False
# 18                            False                        False
# 19                            False                        False
# 20                            False                        False
# 21                            False                        False
# 22                            False                        False
#
#     Series_Title_American Psycho  ...  revenue_543464573  revenue_59667625  \
# 0                          False  ...              False             False
# 1                          False  ...              False             False
# 2                          False  ...              False              True
# 3                          False  ...              False             False
# 4                          False  ...              False             False
# 5                          False  ...              False             False
# 6                          False  ...              False             False
# 7                           True  ...              False             False
# 8                          False  ...              False             False
# 9                          False  ...              False             False
# 10                         False  ...              False             False
# 11                         False  ...              False             False
# 12                         False  ...              False             False
# 13                         False  ...              False             False
# 14                         False  ...              False             False
# 15                         False  ...              False             False
# 16                         False  ...              False             False
# 17                         False  ...              False             False
# 18                         False  ...              False             False
# 19                         False  ...              False             False
# 20                         False  ...              False             False
# 21                         False  ...               True             False
# 22                         False  ...              False             False
#
#     revenue_710644566  revenue_7961889  revenue_83282296  revenue_9500000  \
# 0               False            False             False            False
# 1               False            False             False            False
# 2               False            False             False            False
# 3               False            False             False            False
# 4               False            False             False            False
# 5               False            False             False            False
# 6               False            False             False            False
# 7               False            False             False            False
# 8               False            False             False            False
# 9               False            False             False            False
# 10              False            False             False            False
# 11              False            False              True            False
# 12              False            False             False             True
# 13              False            False             False            False
# 14              False            False             False            False
# 15              False            False             False            False
# 16              False            False             False            False
# 17              False            False             False            False
# 18               True            False             False            False
# 19              False             True             False            False
# 20              False            False             False            False
# 21              False            False             False            False
# 22              False            False             False            False
#
#     country_AU  country_FR  country_GB  Empty_1
# 0         True       False       False     True
# 1         True       False       False    False
# 2         True       False       False     True
# 3         True       False       False    False
# 4         True       False       False     True
# 5        False       False        True    False
# 6         True       False       False    False
# 7         True       False       False    False
# 8         True       False       False     True
# 9         True       False       False    False
# 10        True       False       False     True
# 11        True       False       False    False
# 12        True       False       False     True
# 13        True       False       False     True
# 14        True       False       False     True
# 15        True       False       False    False
# 16        True       False       False    False
# 17        True       False       False     True
# 18        True       False       False     True
# 19        True       False       False    False
# 20       False        True       False    False
# 21        True       False       False    False
# 22        True       False       False     True
#
# [23 rows x 189 columns]
